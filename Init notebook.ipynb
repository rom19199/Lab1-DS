# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting pandas_profiling==3.6.6
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 KB 39.3 MB/s eta 0:00:00
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.0.0-py2.py3-none-any.whl (344 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.5/344.5 KB 67.4 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (1.10.2)
# Collecting PyYAML<6.1,>=5.0.0
#   Downloading PyYAML-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.8/661.8 KB 84.4 MB/s eta 0:00:00
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests<2.29,>=2.24.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (2.28.1)
# Collecting typeguard<2.14,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (1.23.4)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (4.64.1)
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (679 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.8/679.8 KB 15.1 MB/s eta 0:00:00
# Collecting statsmodels<0.14,>=0.13.2
#   Downloading statsmodels-0.13.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 93.7 MB/s eta 0:00:00
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (2.11.3)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (1.2.5)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (3.6.0)
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 KB 27.6 MB/s eta 0:00:00
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (0.12.1)
# Collecting multimethod<1.10,>=1.4
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: attrs>=19.3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (22.1.0)
# Collecting networkx>=2.4
#   Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 106.6 MB/s eta 0:00:00
# Collecting tangled-up-in-unicode>=0.0.4
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 133.7 MB/s eta 0:00:00
# Collecting imagehash
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 KB 35.4 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /shared-libs/python3.9/py/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (9.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas!=1.4.0,<1.6,>1.1->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: joblib>=0.14.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (1.26.12)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 KB 45.6 MB/s eta 0:00:00
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->ydata-profiling->pandas_profiling==3.6.6->-r ./requirements.txt (line 1)) (1.16.0)
# Collecting PyWavelets
#   Downloading PyWavelets-1.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 75.4 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27098 sha256=c859f6751a195f7721a8a93e1747395e1d9f1ed85c011f8c48d7045a8e889038
#   Stored in directory: /root/.cache/pip/wheels/1d/05/04/c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, tangled-up-in-unicode, PyYAML, PyWavelets, patsy, networkx, multimethod, imagehash, visions, statsmodels, phik, ydata-profiling, pandas_profiling
# Successfully installed PyWavelets-1.4.1 PyYAML-6.0 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.9.1 networkx-3.0 pandas_profiling-3.6.6 patsy-0.5.3 phik-0.12.3 statsmodels-0.13.5 tangled-up-in-unicode-0.2.0 typeguard-2.13.3 visions-0.7.5 ydata-profiling-4.0.0
# WARNING: You are using pip version 22.0.4; however, version 23.0 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a5a7a80e-262f-4d26-99b0-d8ffdbda695a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
